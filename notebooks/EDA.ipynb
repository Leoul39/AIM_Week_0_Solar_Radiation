# %%
#Read the datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
benin_df=pd.read_csv('C:/Users/abenet/Desktop/data/benin-malanville.csv')
sierra_df=pd.read_csv('C:/Users/abenet/Desktop/data/sierraleone-bumbuna.csv')
togo_df=pd.read_csv('C:/Users/abenet/Desktop/data/togo-dapaong_qc.csv')

# %%
#In all 3 files there is no null value except for the comments column which is completely null so 
# we need to remove it from all datasets
benin_df.drop('Comments',axis=1,inplace=True)
sierra_df.drop('Comments',axis=1,inplace=True)
togo_df.drop('Comments',axis=1,inplace=True)

# %% [markdown]
# Statistical Analysis

# %%
#Mean, Mode, Median(50%) and STD for benin dataframe
benin_df.describe().round(2)
# Out:
#              GHI        DNI        DHI       ModA       ModB       Tamb  \
# count  525600.00  525600.00  525600.00  525600.00  525600.00  525600.00
# mean      240.56     167.19     115.36     236.59     228.88      28.18
# std       331.13     261.71     158.69     326.89     316.54       5.92
# min       -12.90      -7.80     -12.60       0.00       0.00      11.00
# 25%        -2.00      -0.50      -2.10       0.00       0.00      24.20
# 50%         1.80      -0.10       1.60       4.50       4.30      28.00
# 75%       483.40     314.20     216.30     463.70     447.90      32.30
# max      1413.00     952.30     759.20    1342.30    1342.30      43.80
#
#               RH         WS     WSgust    WSstdev         WD    WDstdev  \
# count  525600.00  525600.00  525600.00  525600.00  525600.00  525600.00
# mean       54.49       2.12       2.81       0.47     153.44       8.58
# std        28.07       1.60       2.03       0.27     102.33       6.39
# ...

# %%
#Mean, Mode, Median(50%) and STD for sierraleone dataframe
sierra_df.describe().round(2)
# Out:
#              GHI        DNI        DHI       ModA       ModB       Tamb  \
# count  525600.00  525600.00  525600.00  525600.00  525600.00  525600.00
# mean      201.96     116.38     113.72     206.64     198.11      26.32
# std       298.50     218.65     158.95     300.90     288.89       4.40
# min       -19.50      -7.80     -17.90       0.00       0.00      12.30
# 25%        -2.80      -0.30      -3.80       0.00       0.00      23.10
# 50%         0.30      -0.10      -0.10       3.60       3.40      25.30
# 75%       362.40     107.00     224.70     359.50     345.40      29.40
# max      1499.00     946.00     892.00    1507.00    1473.00      39.90
#
#               RH         WS     WSgust    WSstdev         WD    WDstdev  \
# count  525600.00  525600.00  525600.00  525600.00  525600.00  525600.00
# mean       79.45       1.15       1.69       0.36     133.04       7.17
# std        20.52       1.24       1.62       0.30     114.28       7.54
# ...

# %%
#Mean, Mode, Median(50%) and STD for togo dataframe
togo_df.describe().round(2)
# Out:
#              GHI        DNI        DHI       ModA       ModB       Tamb  \
# count  525600.00  525600.00  525600.00  525600.00  525600.00  525600.00
# mean      230.56     151.26     116.44     226.14     219.57      27.75
# std       322.53     250.96     156.52     317.35     307.93       4.76
# min       -12.70       0.00       0.00       0.00       0.00      14.90
# 25%        -2.20       0.00       0.00       0.00       0.00      24.20
# 50%         2.10       0.00       2.50       4.40       4.30      27.20
# 75%       442.40     246.40     215.70     422.52     411.00      31.10
# max      1424.00    1004.50     805.70    1380.00    1367.00      41.40
#
#               RH         WS     WSgust    WSstdev         WD    WDstdev  \
# count  525600.00  525600.00  525600.00  525600.00  525600.00  525600.00
# mean       55.01       2.37       3.23       0.56     161.74      10.56
# std        28.78       1.46       1.88       0.27      91.88       5.92
# ...
