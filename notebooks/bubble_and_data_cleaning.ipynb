# %%
#Read the datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
benin_df=pd.read_csv('C:/Users/abenet/Desktop/data/benin-malanville.csv')
sierra_df=pd.read_csv('C:/Users/abenet/Desktop/data/sierraleone-bumbuna.csv')
togo_df=pd.read_csv('C:/Users/abenet/Desktop/data/togo-dapaong_qc.csv')

# %% [markdown]
# bubble analysis for togo

# %%
tg=togo_df[:1000]
tg.plot(kind='scatter',x='GHI',y='Tamb',s='RH')
tg.plot(kind='scatter',x='WS',y='Tamb',s='RH')
tg.plot(kind='scatter',x='WS',y='GHI',s='RH')
# Out:
# <Axes: xlabel='WS', ylabel='GHI'>

# %% [markdown]
# bubble analysis for sierraleone

# %%
tg=sierra_df[:1000]
tg.plot(kind='scatter',x='GHI',y='Tamb',s='RH')
tg.plot(kind='scatter',x='WS',y='Tamb',s='RH')
tg.plot(kind='scatter',x='WS',y='GHI',s='RH')
# Out:
# <Axes: xlabel='WS', ylabel='GHI'>

# %% [markdown]
# bubble analysis for benin

# %%
tg=benin_df[:1000]
tg.plot(kind='scatter',x='GHI',y='Tamb',s='RH')
tg.plot(kind='scatter',x='WS',y='Tamb',s='RH')
tg.plot(kind='scatter',x='WS',y='GHI',s='RH')
# Out:
# <Axes: xlabel='WS', ylabel='GHI'>

# %% [markdown]
# Data cleaning is done by simply removing the comments column from all 3 datasets because it has nothing

# %%
benin_df.drop('Comments',axis=1,inplace=True)
sierra_df.drop('Comments',axis=1,inplace=True)
togo_df.drop('Comments',axis=1,inplace=True)
